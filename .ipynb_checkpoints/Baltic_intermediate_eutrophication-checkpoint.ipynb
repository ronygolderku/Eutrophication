# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)
#
# # COPERNICUS MARINE SERVICE BALTIC SEA TRAINING
#
# <div style="text-align: right"><i> INTERMEDIATE LEVEL </i></div>
#
# ***
# <center><h1> Assessing the evolution of the eutrophication of the Baltic Sea </h1></center>
#
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Run" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# # Table of contents
# - [1. Introduction](#1.-Introduction)
# - [2. Set up Python](#2.-Set-up-Python)
#     - [2.1 Required Python modules](#2.1-Required-Python-modules)
#     - [2.2. Set up OPeNDAP](#2.2.-Set-up-OPeNDAP)
#     - [2.3. Presentation of the product used](#2.3.-Presentation-of-the-product-used)
# - [3. Analyse the evolution of the Baltic Sea parameters](#3.-Analyse-the-evolution-of-the-Baltic-Sea-parameters)
#     - [3.1. Load the product](#3.1.-Load-the-product)
#     - [3.2. Calculate the regional average of the parameters](#3.2.-Calculate-the-regional-average-of-the-parameters)
#     - [3.3. Plot the evolution of the parameters](#3.3.-Plot-the-evolution-of-the-parameters)
#     - [3.4. Calculate the yearly average](#3.4.-Calculate-the-yearly-average)
#     - [3.5. Plot the interannual variations of the parameters](#3.5.-Plot-the-interannual-variations-of-the-parameters)
#     - [3.6. Analyse the results](#3.6.-Analyse-the-results)
# - [4. Monitor the hypoxia of the Baltic Sea](#4.-Monitor-the-hypoxia-of-the-Baltic-Sea)
#     - [4.1. Convert the units](#4.1.-Convert-the-units)
#     - [4.2. Study the vertical distribution of oxygen](#4.2.-Study-the-vertical-distribution-of-oxygen)
#     - [4.3. Locate the hypoxic regions](#4.3.-Locate-the-hypoxic-regions)
#     - [4.4. Analyse hypoxia evolution](#4.4.-Analyse-hypoxia-evolution)
# - [5. Conclusion](#5.-Conclusion)
#     - [5.1. Exercises](#5.1.-Exercises)
#     - [5.2. Go further](#5.2.-Go-further)

# %% [markdown]
# # 1. Introduction
# [Go back to the "Table of contents"](#Table-of-contents)
#
# Welcome to this Copernicus Marine Service training over the Baltic Sea !
#
# This is the second notebook of the training workshop dedicated to the Baltic Sea. It is designed for intermediate level users. The first notebook, dedicated to beginners, explains the fundamentals of Python to manipulate and visualize the Copernicus Marine Service products. In this notebook, we are going to use a set of products in order to study a concerning issue of the Baltic Sea : its eutrophication.
#
# Eutrophication occurs when an environment becomes enriched with nutrients running off from the land to the sea. These inputs increase the supply of organic matter to the ecosystem which leads to excessive concentrations of algae and microscopic organisms at the sea surface. This green coat prevents the light penetration and oxygen absorption necessary for underwater life. The oxygen depletion caused by these extreme algal bloom episodes can be harmful or noxious, can destroy aquatic life in affected areas and threat human and wildlife health. In the worst cases, eutrophication creates "dead zones" where life cannot be sustained.
#
# The input nutrients from land are usually nitrogen and phosphorus, which origniate from the excessive use of fertilisers and detergents, as well as fish farming waste, industrial discharge and sewage.  In 1988, The Baltic Marine Environment Protection Commission (Helsinki Commission - HELCOM) agreed to take actions to reduce nutrient loading into the Baltic Sea. The aim of this notebook is therefore to assess the results of these measures and to monitor the evolution of the eutrophication of the Baltic Sea.
#
#
# <left>
#     <img src="img/eutrophication-diagram.svg" width="500">
# </left>
#
# Eutrophication phenomenon - [deq.utah.gov]('https://deq.utah.gov/water-quality/nutrients')

# %% [markdown]
# # 2. Set up Python
# [Go back to the "Table of contents"](#Table-of-contents)
#
# ## 2.1 Required Python modules
# [Go back to the "Table of contents"](#Table-of-contents)
#
# The Jupyter Notebook must be set up with all the necessary available tools from the Jupyter Notebook ecosystem. Here is the list of the modules we will be using in this exercise.
#
# | Module name | Description |
# | :---: | :---|
# | **numpy** | [NumPy](https://numpy.org/) is the fundamental package for scientific computing with Python and for managing ND-arrays. |
# | **xarray** | [Xarray](http://xarray.pydata.org/en/stable/) is a very user friendly librairy to manipulate NetCDF files within Python. It introduces labels in the form of dimensions, coordinates and attributes on top of raw NumPy-like arrays, which allows for a more intuitive, more concise, and less error-prone developer experience. |
# | **matplotlib** |[Matplotlib](https://matplotlib.org/) is a Python 2D plotting library which produces high quality figures. |
# | **cartopy** |[Cartopy](https://scitools.org.uk/cartopy/docs/latest/) is a library for plotting maps and geospatial data analyses in Python. |

# %%
# Import libraries
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.patches as mpatches
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# To avoid warning messages
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2.2. Set up OPeNDAP
# [Go back to the "Table of contents"](#Table-of-contents)
#
# In the [first notebook](../Beginner-Overview/Baltic_beginner_overview.ipynb), we have seen that the Copernicus Marine Service Products could be used directly, without having to download any file, thanks to the OPeNDAP service. A specific Python script has been developped for this workshop and will give you access to the Copernicus Marine Service products. To use it, run the following cell and enter your credentials.
#
# In the following sections, you will be able to use the products either from the files which have already been downloaded, or thanks to OPeNDAP service, depending on what you prefer !

# %%
# %run opendap_config.py
# Out:
# Enter your Copernicus Marine Service username:  efouchet
# Enter your password:  ·········

# %% [markdown]
# ## 2.3. Presentation of the product used
# [Go back to the "Table of contents"](#Table-of-contents)
#
# In this notebook, we are going  to use the Baltic Sea Biogeochemistry Reanalysis model, with the **monthly means** of the biogeochemical parameters from **1993 to 2020**. Reanalysis models combine the advantages of a model simulation constrained by existing measurements. Here is a brief overview of the product's characteristics:
#
#
# | Parameter | Value |
# | :---: | :---|
# | **Variables used** | o2 *(oxygen concentration)*, chl *(concentration of chlorophyll)*, no4 *(concentration of Nitrate)* |
# | **Product identifier** |[BALTICSEA_REANALYSIS_BIO_003_012](https://resources.marine.copernicus.eu/product-detail/BALTICSEA_REANALYSIS_BIO_003_012/INFORMATION) |
# | **Spatial resolution** | 4km x 4km |
# | **Temporal resolution** | monthly mean |
# | **Temporal coverage** | from 1993-01-01 to 2020-12-31 |
# | **Vertical coverage** |from -700m to 0m |
#
# <center>
#     <img src="img/BALTICSEA_REANALYSIS_BIO_003_012.png" width="700">
# </center>
#
# **Description** : This CMEMS Baltic Sea Biogeochemical Reanalysis product provides a biogeochemical reanalysis for the whole Baltic Sea area, inclusive the Transition Area to the North Sea, from January 1993 and up to minus 1-1.5 year compared to real time. The product is produced by using the ice-ocean model NEMO-Nordic (based on NEMO-3.6, Nucleus for European Modelling of the Ocean) coupled with the biogeochemical model SCOBI (Swedish Coastal and Ocean Biogeochemical model) together with a LSEIK data assimilation scheme. All variables are available as daily means as well as monthly means, and include nitrate, phosphate, ammonium, dissolved oxygen and chlorophyll-a. The observation types used in the data assimilation are nitrate, phosphate, ammonium, and dissolved oxygen. The reanalysis has been produced using 72-hour cycling, which implies that every 72 hours, all available observations are assimilated into the model before a 72-hour forecast is made.
#
# [See DOI (product)](https://doi.org/10.48670/moi-00012)
#
# **For detailed information about the product, please consult the document:** [Product User Manual (PUM)](https://catalogue.marine.copernicus.eu/documents/PUM/CMEMS-BAL-PUM-003-012.pdf)
#
# **For information about the quality of the product, please consult the document:** [Quality Information Document (QUID)](https://catalogue.marine.copernicus.eu/documents/QUID/CMEMS-BAL-QUID-003-012.pdf)

# %% [markdown]
# # 3. Analyse the evolution of the Baltic Sea parameters
# [Go back to the "Table of contents"](#Table-of-contents)
#
# We are now all set to begin our study of the eutrophication of the Baltic Sea. In this first section, we are going to analyse the evolution of the eutrophication through the evolution of the nutrient input (Nitrate concentration), the algae blooms (Chlorophyll concentration), and sea hypoxia (Oxygen concentration) in the Baltic Sea.
#
# ## 3.1. Load the product
# [Go back to the "Table of contents"](#Table-of-contents)
#
# As we have seen before, you have two options to load the product : you can either use the files that have been downloaded and stored in the `data/` folder, or use the OPeNDAP service.
#
# We are going to load two files : the first one, under the Python variable `chl_N_O` contains the surface parameters (nitrate, chlorophyll and oxygen) from 1993 to 2020, whereas the second one `o2` contains the oxygen concentration of all the depths and from 1993 to 2020.
#
# In the following cell, you can comment/uncomment the lines and select the option you prefer. You can then check the dataset coordinates and variables and make sure that both methods output the same information.

# %%
# Open the datasets with OPeNDAP
#chl_N_O = xr.open_dataset('https://my.cmems-du.eu/thredds/dodsC/dataset-reanalysis-scobi-monthlymeans').sel(depth=0,method='nearest')[['chl','no3','o2']]
#o2 = xr.open_dataset('https://my.cmems-du.eu/thredds/dodsC/dataset-reanalysis-scobi-monthlymeans')[['o2']]

# Open the datasets
chl_N_O = xr.open_dataset('data/chl_N_O.nc')
o2 = xr.open_dataset('data/o2_all_depths.nc')

# %%
# check what the dataset contains
chl_N_O
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 336, depth: 1, latitude: 523, longitude: 383)
# Coordinates:
#   * depth      (depth) float32 1.501
#   * latitude   (latitude) float32 48.49 48.53 48.56 48.59 ... 65.82 65.86 65.89
#   * time       (time) datetime64[ns] 1993-01-16T12:00:00 ... 2020-12-16T12:00:00
#   * longitude  (longitude) float32 9.014 9.069 9.125 9.18 ... 30.12 30.18 30.24
# Data variables:
#     o2         (time, depth, latitude, longitude) float32 ...
#     no3        (time, depth, latitude, longitude) float32 ...
#     chl        (time, depth, latitude, longitude) float32 ...
# Attributes: (12/24)
#     references:                                 http://www.smhi.se
#     institution:                                Swedish Meterological and Hyd...
#     history:                                    See source and creation_date ...
#     Conventions:                                CF-1.5
#     contact:                                    servicedesk_cmems@mercator-oc...
# ...

# %% [markdown]
# ## 3.2. Calculate the regional average of the parameters
# [Go back to the "Table of contents"](#Table-of-contents)
#
# We will calculate the average value of each of the surface Nitrate, Chlorophyll and Oxygen concentrations over the whole Baltic Sea region (average on the longitude and latitude coordinates). .

# %%
# Calculate the average parameters
chl_N_O_average = chl_N_O.mean('latitude').mean('longitude')

# Check the results
chl_N_O_average
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 336, depth: 1)
# Coordinates:
#   * depth    (depth) float32 1.501
#   * time     (time) datetime64[ns] 1993-01-16T12:00:00 ... 2020-12-16T12:00:00
# Data variables:
#     o2       (time, depth) float32 378.3 391.5 402.7 411.0 ... 316.3 333.6 356.8
#     no3      (time, depth) float32 12.67 13.69 13.79 12.56 ... 1.668 2.451 3.154
#     chl      (time, depth) float32 0.2571 0.3624 0.9871 ... 1.671 1.084 0.6298

# %% [markdown]
# ## 3.3. Plot the evolution of the parameters
# [Go back to the "Table of contents"](#Table-of-contents)
#
# Let's plot the evolution of the parameters over time, with the 28 years available in the product.

# %%
# Define the characteristics of the plot  
f = plt.figure(figsize=(12,12))
ax1 = f.add_subplot(311)
ax2 = f.add_subplot(312)
ax3 = f.add_subplot(313)
f.subplots_adjust(top=0.8,bottom=0.05,hspace = 0.5)

# First plot : Nitrate
ax1.set_title("Average surface nitrate concentration",fontsize=24)
ax1.grid()
ax1.set_ylabel("mmol/m3",fontsize=18)
ax1.plot(chl_N_O_average.time,chl_N_O_average.no3,c='tab:blue',linewidth=2)
f.autofmt_xdate()

# Second plot : Chlorophyll
ax2.set_title("Average surface chlorophyll concentration",fontsize=24)
ax2.grid()
ax2.set_ylabel("mg/m3",fontsize=18)
ax2.plot(chl_N_O_average.time,chl_N_O_average.chl,c='tab:green',linewidth=2)

# Third plot : Oxygen
ax3.set_title("Average surface oxygen concentration",fontsize=24)
ax3.grid()
ax3.set_ylabel("mmol/m3",fontsize=18)
ax3.plot(chl_N_O_average.time,chl_N_O_average.o2,c='tab:orange',linewidth=2)

# %% [markdown]
# The above figure shows the variations of the Baltic Sea biogeochemical parameters from 1993 to 2020. We can already see some trends : the nitrate and chlorophyll surface concentrations seem to be decreasing over the years, whereas the oxygen surface concentration seems to be stable.
#
# ## 3.4. Calculate the yearly average
# [Go back to the "Table of contents"](#Table-of-contents)
#
#
# The previous plots have used the spatially averaged monthly values of the parameters and we displayed their seasonal variations as well as the interannual ones. In the next cell, we are going to calculate the annual values with the [`xarray.groupby` method](https://xarray.pydata.org/en/stable/generated/xarray.DataArray.groupby.html). We will therefore be able to focus the analysis on the interannual variations of the sea parameters.

# %%
# Group the data by year and calculate the average for each year 
chl_N_O_average_annual = chl_N_O_average.groupby('time.year').mean('time')

# Check the results
chl_N_O_average_annual
# Out:
# <xarray.Dataset>
# Dimensions:  (year: 28, depth: 1)
# Coordinates:
#   * depth    (depth) float32 1.501
#   * year     (year) int64 1993 1994 1995 1996 1997 ... 2016 2017 2018 2019 2020
# Data variables:
#     o2       (year, depth) float32 366.3 365.1 364.2 365.7 ... 356.8 358.6 352.1
#     no3      (year, depth) float32 9.299 9.324 8.116 7.417 ... 2.954 2.134 2.317
#     chl      (year, depth) float32 2.807 2.603 2.653 2.437 ... 1.693 1.304 1.583

# %% [markdown]
# You can see from the previous cell output that the dataset does not have the `time` coordinate anymore, as it has been replaced with the `year` coordinate. The `o2` variable now contains the spatially and temporally averaged annual values of the parameters.
#
# ## 3.5. Plot the interannual variations of the parameters
# [Go back to the "Table of contents"](#Table-of-contents)
#
# Let's plot their evolution !

# %%
# Define the characteristics of the plot  
f = plt.figure(figsize=(12,12))
ax1 = f.add_subplot(311)
ax2 = f.add_subplot(312)
ax3 = f.add_subplot(313)
f.subplots_adjust(top=0.8,bottom=0.05,hspace = 0.5)

# First plot : Nitrate
ax1.set_title("Average surface nitrate concentration",fontsize=24)
ax1.grid()
ax1.set_ylabel("mmol/m3",fontsize=18)
ax1.plot(chl_N_O_average_annual.year,chl_N_O_average_annual.no3,c='tab:blue',linewidth=2)
f.autofmt_xdate()

# Second plot : Chlorophyll
ax2.set_title("Average surface chlorophyll concentration",fontsize=24)
ax2.grid()
ax2.set_ylabel("mg/m3",fontsize=18)
ax2.plot(chl_N_O_average_annual.year,chl_N_O_average_annual.chl,c='tab:green',linewidth=2)

# Third plot : Oxygen
ax3.set_title("Average surface oxygen concentration",fontsize=24)
ax3.grid()
ax3.set_ylabel("mmol/m3",fontsize=18)
ax3.plot(chl_N_O_average_annual.year,chl_N_O_average_annual.o2,c='tab:orange',linewidth=2)

# %% [markdown]
# ## 3.6. Analyse the results
# [Go back to the "Table of contents"](#Table-of-contents)
#
# The plots from the previous cells confirm the decreasing trend for the three parameters during the period 1993-2020. The lower surface nitrate concentrations in the 2010s indicate that the HELCOM measures have been efficient in reducing the nutrient input from land. As a result, the surface chlorophyll is also decreasing and returning to more sustainable levels ! However, the oxygen concentration plot shows that, although the inputs were reduced, the oxygen concentration in the Baltic Sea has continued to decrease until the early 2000s. The situation now seems to remain stable but the Baltic Sea still locally suffers from oxygen depletion : hypoxia.
#
# The following statement from [stateofthebalticsea.helcom.fi](https://stateofthebalticsea.helcom.fi/pressures-and-their-status/eutrophication/) confirms our observations and analyses:
#
# *"Nutrient inputs from land have decreased as a result of regionally reduced nutrient loading, but the effect of these measures has not yet been detected. Although signs of improvement are seen in some areas, effects of past and current nutrient inputs still predominate the overall status."*
#
# The hypoxia should not only be assessed on the sea surface but also over all the water column. In the next sections, we are going to analyse the evolution of the Baltic Sea hypoxia, diving into the deeper layers.

# %% [markdown]
# # 4. Monitor the hypoxia of the Baltic Sea
# [Go back to the "Table of contents"](#Table-of-contents)
#
# In this section, we are going to study the oxygen concentration in the Baltic Sea and provide an assessment of the hypoxia. As previously mentioned, the algae blooms prevent the light absorption in the deeper sea levels, which is one of the reasons for oxygen depletion mostly occuring near the sea floor. A conventional criterion for water to be considered hypoxic is a dissolved oxygen concentration lower than **2 mg of O2 / L** at the bottom of the sea floor (see [oceanservice.noaa.gov](https://oceanservice.noaa.gov/hazards/hypoxia/)). In the following sections, we are going to locate the regions which have suffered and still suffer from hypoxia depending on this criterion.
#
# ## 4.1. Convert the units
# [Go back to the "Table of contents"](#Table-of-contents)
#
# We are going to use the `o2` variable set before. This variable contains the oxygen concentrations for all the depths and dates included in the model.

# %%
# Check the products variables
o2
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 336, depth: 56, latitude: 121, longitude: 91)
# Coordinates:
#   * depth      (depth) float32 1.501 4.513 7.54 10.58 ... 666.8 688.9 711.1
#   * latitude   (latitude) float32 53.99 54.02 54.06 54.09 ... 57.92 57.96 57.99
#   * time       (time) datetime64[ns] 1993-01-16T12:00:00 ... 2020-12-16T12:00:00
#   * longitude  (longitude) float32 17.01 17.07 17.12 17.18 ... 21.9 21.96 22.01
# Data variables:
#     o2         (time, depth, latitude, longitude) float32 ...
# Attributes: (12/24)
#     references:                                 http://www.smhi.se
#     institution:                                Swedish Meterological and Hyd...
#     history:                                    See source and creation_date ...
#     Conventions:                                CF-1.5
#     contact:                                    servicedesk_cmems@mercator-oc...
#     comment:                                    Provided by SMHI as a Coperni...
# ...

# %% [markdown]
# You can see from the previous cell output that the unit of the oxygen concentration is **mmol/m3**. The threshold we are using to diagnose hypoxia is 2 **mg/L** at the bottom of the sea floor. In order to compare our dataset to this threshold, we are going to convert this the *mmol/m3* into *mg/L*. (Tips : the O2 molar mass is 32 g/mol)

# %%
# Convert the units 
o2 = o2 * 32 / 1000

# %% [markdown]
# ## 4.2. Study the vertical distribution of oxygen
# [Go back to the "Table of contents"](#Table-of-contents)
#
# First, let's have a look at the vertical distribution of the oxygen concentration. In the next cells we are setting the location of 4 points and one date, then selecting the model values at these locations and dates and finally plotting the vertical profiles.

# %%
# Define the coordinates of the points to study
lon1, lat1 = 17.44 , 58.02
lon2, lat2 = 20.37 , 55.37
lon3, lat3 = 19.93 , 57.49
lon4, lat4 = 19.43 , 61.69

# Define the date to study
date = '2020-11-01T00'

# Select the product at this location and date and select the variable o2
o2_1 = o2.sel(longitude = lon1, latitude = lat1, time = date, method = 'nearest').o2
o2_2 = o2.sel(longitude = lon2, latitude = lat2, time = date, method = 'nearest').o2
o2_3 = o2.sel(longitude = lon3, latitude = lat3, time = date, method = 'nearest').o2
o2_4 = o2.sel(longitude = lon4, latitude = lat4, time = date, method = 'nearest').o2

# %%
# Define the characteristics of the plot
f = plt.figure(figsize=(8,12))                                       # create a figure and define its size
ax = f.add_subplot(111)                                              # create the axes of the plot
ax.grid()                                                            # add the grid lines
ax.set_title("Oxygen concentration",fontsize=24)                     # add the figure title
ax.invert_yaxis()                                                    # reverse the y axis
ax.set_xlabel("mg/L",fontsize=18)                                    # set x axis label
ax.set_ylabel("Depth (m)",fontsize=20)                               # set y axis label 


# Plot the vertical profiles 
ax.plot(o2_1,o2_1['depth'],'tab:blue')               
ax.plot(o2_2,o2_2['depth'],'tab:orange')                             
ax.plot(o2_3,o2_3['depth'],'tab:green')                              
ax.plot(o2_4,o2_4['depth'],'tab:red')      

# Add the threshold value
ax.axvline(x = 2, ls='--',color = 'tab:red',label='Hypoxia threshold')

# Display the locations of the glider on a mini map
ax_mini_map = f.add_axes([0.73, 0.91, 0.2, 0.15], projection=ccrs.PlateCarree()) # create the minimap and define its projection
gl = ax_mini_map.gridlines(draw_labels=True)                                     # add the coastlines
gl.right_labels = False                                                          # remove latitude labels on the right
gl.top_labels = False                                                            # remove longitude labels on the top
ax_mini_map.add_feature(cfeature.LAND, zorder=0, edgecolor='k')                  # add land mask 
ax_mini_map.set_extent([14, 25, 54, 65],crs=ccrs.PlateCarree())          # define the extent of the map [lon_min,lon_max,lat_min,lat_max]
ax_mini_map.scatter(lon1, lat1, 10,'tab:blue',transform=ccrs.PlateCarree())         # plot location of point 1
ax_mini_map.scatter(lon2, lat2, 10,'tab:orange',transform=ccrs.PlateCarree())       # plot location of point 2
ax_mini_map.scatter(lon3, lat3, 10,'tab:green',transform=ccrs.PlateCarree())        # plot location of point 3
ax_mini_map.scatter(lon4, lat4, 10,'tab:red',transform=ccrs.PlateCarree())          # plot location of point 4
ax.legend(loc="upper left")                                              # add the legend

#Save figure
#plt.savefig('out/temp_vertical_profile.png')

# %% [markdown]
# The previous cell's output shows that the highest oxygen concentrations are located in the surface layer.
# There are several reasons for this distribution :
# - the oxygen dissolves into the ocean from the atmosphere at the surface ;
# - the surface water is where oxygen is produced by phytoplankton through photosynthesis;
# - the deeper water is too far from the surface for any atmospheric exchange, and there is not enough light to support photosynthesis;
# - the oxygen is removed from the deeper water through the respiration of deep water organisms and the decomposition of organic material.
#
# You can learn more about the sea oxygen concentration on this [article](https://rwu.pressbooks.pub/webboceanography/chapter/5-4-dissolved-gases-oxygen/)!

# %% [markdown]
# ## 4.3. Locate the hypoxic regions
# [Go back to the "Table of contents"](#Table-of-contents)
#
# We are now going to locate the regions which suffer from hypoxia, our criteria still being the oxygen concentration on the sea floor. The previous vertical profiles have shown that the oxygen concentration was the lowest at the bottom of the sea. We are therefore going to select the minimum oxygen value in the water column, for each point of the region and for all date times. We will then select a date time and see the regions where the Baltic Sea was hypoxic.

# %%
# Select the minimum oxygen value 
o2_min = o2.min('depth')

# See the result
o2_min
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 121, time: 336, longitude: 91)
# Coordinates:
#   * latitude   (latitude) float32 53.99 54.02 54.06 54.09 ... 57.92 57.96 57.99
#   * time       (time) datetime64[ns] 1993-01-16T12:00:00 ... 2020-12-16T12:00:00
#   * longitude  (longitude) float32 17.01 17.07 17.12 17.18 ... 21.9 21.96 22.01
# Data variables:
#     o2         (time, latitude, longitude) float32 nan nan nan ... 11.92 nan

# %%
# Define the date to display
date = '2020-08-16'

# Select the model oxygen variable at this date
o2_min_date = o2_min.sel(time=date).squeeze().o2

# Define the characteristics of the plot
f = plt.figure(figsize=(10, 8))                                                    # create a figure and define its size
ax = plt.axes(projection=ccrs.PlateCarree())                                       # create an ax and select the projection of the map
ax.coastlines()                                                                    # add the coastlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)                        # add the longitude / latitude lines
gl.right_labels = False                                                            # remove latitude labels on the right
gl.top_labels = False                                                              # remove longitude labels on the top
ax.add_feature(cfeature.LAND, zorder=1, edgecolor='k')                             # add land mask
ax.set_extent([14, 25, 52, 60],crs=ccrs.PlateCarree())                             # define the extent of the map [lon_min,lon_max,lat_min,lat_max]

# Plot the sea surface temperature, set the min/max values of the colorbar and the colormap to use
# im = ax.pcolor(o2_2005_2014['longitude'].data, o2_2005_2014['latitude'].data,o2_2005_2014,shading='nearest',cmap='plasma')
#im = ax.pcolor(o2_min['longitude'].data, o2_min['latitude'].data,o2_min,shading='nearest',cmap='plasma')
im = ax.contourf(o2_min_date['longitude'].data, o2_min_date['latitude'].data,o2_min_date,[-10,2,15],cmap='RdYlGn')

# Add the titles and legend
f.suptitle('Hypoxia assessment on ' + date ,fontsize=25)                           # add a title to the figure
cbar = f.colorbar(im,ax=ax)                                                        # add the colorbar
cbar.ax.set_yticklabels(['Hypoxic < 2 mg/L', 'Hypoxia threshold = 2 mg/L', 'Healthy > 2 mg/L'])                     # add the labels of the colorbar
# Out:
# [Text(1, -10.0, 'Hypoxic < 2 mg/L'),
#  Text(1, 2.0, 'Hypoxia threshold = 2 mg/L'),
#  Text(1, 15.0, 'Healthy > 2 mg/L')]

# %% [markdown]
# ## 4.4. Analyse hypoxia evolution
# [Go back to the "Table of contents"](#Table-of-contents)
#
# The last steps of our study will be to calculate the area of our sub-region that is affected by hypoxia. For each year, we will state that a pixel of the model is hypoxic if the average of the bottom oxygen concentration, over the year, is below the threshold of 2mg/L. Note that this criterion is just a suggestion and some other ones, such as the median oxygen value over the year, may also be relevant.
#
# To do this study, we will be using the functions [`xarray.where`](https://xarray.pydata.org/en/stable/generated/xarray.where.html) to apply a filter on the regions where the bottom oxygen is below the threshold, and [`xarray.count`](https://xarray.pydata.org/en/stable/generated/xarray.DataArray.count.html) to calculate the number of pixels which pass the filter. Knowing that the spatial resolution of the model is 4 km x 4 km, each pixel has an area of 16 km² !
#
#
# In the following cell, we are going group the `o2_min` Python variable by year, like we did in [section 3.4.](#3.4.-Calculate-the-yearly-average) We will then make a loop on each year and see the how hypoxia has evolved in the Baltic Sea over the 28 last years.

# %%
# Calculate the yearly average
o2_min_year = o2_min.groupby('time.year').mean('time')

# Initialize the lists to be ploted
years = []
areas = []

# Loop on the years
for year in range(1993,2020):
    o2_min_year_date = o2_min_year.sel(year=year)             # Select the year
    area = o2_min_year_date.o2.where(o2_min_year_date<2).count().o2 * 16      # Calculate the area
    areas.append(float(area))
    years.append(year)

# Define the characteristics of the plot
f = plt.figure(figsize=(8,12))                                # create a figure and define its size
ax = f.add_subplot(111)                                       # create the axes of the plot
ax.set_title("Hypoxic water area",fontsize=24)                     # add the figure title
ax.set_xlabel("Years",fontsize=18)                        # set x axis label
ax.set_ylabel("km²",fontsize=20)                               # set y axis label 

# Plot the bar charts 
ax.bar(years,areas)
# Out:
# <BarContainer object of 27 artists>

# %% [markdown]
# The previous chart shows that the eutrophication of the studied region seems to remain stable since the 2000s, although some years can be critical.
#
#
# # 5. Conclusion
# [Go back to the "Table of contents"](#Table-of-contents)
#
# This study constitutes an overview of the Baltic Sea eutrophication situation. We have studied the evolution of the nutrient input into the sea, and then the chlorophyll and oxygen concentration response. We have studied the vertical distribution of the oxygen concentration, located the hypoxic regions and monitored the evolution of areas affected by hypoxia in the Baltic Sea. These analyses show that although the nutrient input has storngly decreased from the 1990s, the oxygen depletion has kept growing until the 2000s. In 2020, the eutrophication of the Baltic Sea seemed to remain stable and does not spread anymore, but the hypoxia levels are still high.
#
#
# ## 5.1. Exercises
# [Go back to the "Table of contents"](#Table-of-contents)
#
# Here is a set of exercises we propose for you to go further into the analysis. There are 3 levels depending on how much Python code you need to write to answer the questions. If you need help, do not hesitate to contact the service desk : servicedesk.cmems@mercator-ocean.eu !
#
# **Beginners** :
# - In [Section 3.2.](#3.2.-Calculate-the-regional-average-of-the-parameters) we have studied the parameters with their average over the whole Baltic Sea. Try to define a sub-region, to calculate the average on this region, and to reproduce the plots !
# - In [Section 4.2.](#4.2.-Study-the-vertical-distribution-of-oxygen) we have plotted the vertical profiles of the oxygen concentration for 4 different points. Try to set some other locations !
# - In [Section 4.3.](#4.3.-Locate-the-hypoxic-regions) we have assessed the hypoxia in the region for one precise date. Try to change this date and see how the hypoxia has evolved.
#
# **Intermediate** :
# - If you have changed the locations of the profiles to plot in [Section 4.2.](#4.2.-Study-the-vertical-distribution-of-oxygen), you may have seen that some oxygen concentration had negative values.  This happens when the sea has absolutely no oxygen and hydrogen sulfide occur : this is called anoxia. Try to reproduce the map from [Section 4.3.](#4.3.-Locate-the-hypoxic-regions) with this third category of water condition !
# - In [Section 4.3.](#4.3.-Locate-the-hypoxic-regions) we have assessed the hypoxia in the region for one precise date. Try to make a loop on all the dates and display an animation of the evolution of the hypoxia of the region (check on the [first notebook](../Beginner-Overview/Baltic_beginner_overview.ipynb) to learn how to make an animation) !
# - In [Section 4.4](#4.4.-Analyse-hypoxia-evolution), the chart shows the area of the region which suffers from hypoxia. Try to reproduce this chart by calculating the proportion of the sea, and display a result in % !
#
# **Experts** :
# - On the [HELCOM website](https://helcom.fi/baltic-sea-trends/indicators/), you can have a look at the other indicators which are used to monitor the eutrophication of the Baltic Sea. Many of them can be found in the Copernicus Marine Service catalogue ! You can try to use them and see if you have the same results as in this study.
# - The evolution of the eutrophication does not only depend on the nutrient input. Some other physical parameter, such as the sea temperature or the sea ice coverage can also encourage algae blooms and therefore lead to eutrophication. These parameters are also available in the Copernicus Marine Service catalogue : have a look at the [Baltic Sea Physics Reanalysis model](https://resources.marine.copernicus.eu/product-detail/BALTICSEA_REANALYSIS_PHY_003_011/INFORMATION) and try to visualize the correlation between the eutrophication and the global warming !
#
#
# ## 5.2. Go further
# [Go back to the "Table of contents"](#Table-of-contents)
#
# To go further, you can have a look at the [Ocean State Report](https://marine.copernicus.eu/access-data/ocean-state-report), an annual publication of the Copernicus Marine Service and Mercator Ocean International providing a comprehensive, state-of-the-art report on the current state, natural variations, and ongoing changes in the global ocean and European regional seas. You will find a whole section on eutrophication in the summary, and a specific assessment of the eutrophication in the Baltic Sea in the full report.
#
# You may also be interested in this [article](https://iopscience.iop.org/article/10.1088/2515-7620/ac0cc4/pdf), which also uses the Copernicus Marine Service reanalysis models to assess the hypoxia in the Baltic Sea !

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>Congratulations !!</b><br>
#
# ---
#
# ##### And thank you for your attention! :)
#
#
# We hope you enjoyed this second Jupyter Notebook training on the Baltic Sea.
#
# You now have plenty of tools to study the eutrophication of the Baltic Sea. Feel free to re-use and adapt all the Python scripts of this notebook to your needs !
#
# This training course is over but we'd love to hear from you about how we could improve it (topics, tools, storytelling, format, speed etc). If you have any question, do not hesitate to contact us at [servicedesk.cmems@mercator-ocean.eu](servicedesk.cmems@mercator-ocean.eu) !
